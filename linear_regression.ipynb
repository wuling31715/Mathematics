# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 作業：線性函數預測非線性函數

# %% [markdown]
# $ y = sin(x) + b $

# %%
X = np.linspace(0, 20, 1000)
Y = np.sin(X) + 2 * np.random.rand(1000)
plt.figure(figsize=(20, 10))
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# $ \text{let x' = sin(x)} $

# %% [markdown]
# $ \rightarrow y = ax' + b $

# %%
X2 = np.sin(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X2, Y)
print(X_train.shape)
print(X_test.shape)
# Out:
# (750,)
# (250,)

# %%
X_train = X_train.reshape(X_train.shape[0], 1)
Y_train = Y_train.reshape(Y_train.shape[0], 1)
X_test = X_test.reshape(X_test.shape[0], 1)
Y_test = Y_test.reshape(Y_test.shape[0], 1)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (750, 1)
# (250, 1)
# (750, 1)
# (250, 1)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X_train, Y_train)
print(model.coef_)
print(model.intercept_)
print(model.score(X_test, Y_test))
# Out:
# [[1.00126592]]
# [1.01639027]
# 0.5929841630221513
# /Users/DannyShau/anaconda/envs/py3.6/lib/python3.6/site-packages/sklearn/linear_model/base.py:509: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)

# %% [markdown]
# $ y = 1.001x' + 1.01 $

# %%
X2 = X2.reshape(X2.shape[0], 1)
Y_predict = model.predict(X2)
plt.figure(figsize=(20, 10))
plt.plot(X2, Y_predict)
plt.show()

# %% [markdown]
# $ y = sin(x) + 1.01 $

# %%
X = X.reshape(X.shape[0], 1)
Y_predict = model.predict(X2)
plt.figure(figsize=(20, 10))
plt.plot(X, Y_predict)
plt.show()
