# %% [markdown]
# ![Alt text](iphonex.jpg)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $ iPhone \hspace{0.1cm} x $

# %%
y = np.ones(100)
x = np.arange(-50, 50)
plt.plot(x, y)

# %% [markdown]
# $ iPhone \hspace{0.1cm} y=x $

# %%
y = x
plt.plot(x, y)

# %% [markdown]
# $ iPhone \hspace{0.1cm} y=x^2 $

# %%
y = y * x
plt.plot(x, y)

# %% [markdown]
# $ iPhone \hspace{0.1cm} y=x^3 $

# %%
y = y * x
plt.plot(x, y)
